# %% [markdown]
# # STAT 440 Statistical Data Management - Fall 2021
# ## Homework03
# ### Due: Monday October 11, 2021 11:59 pm US Central Time
# #### Created by Course Staff
#
# Grading Rubric (per question):
# 2 points if complete and correct
# 1 point if incomplete or incorrect
# 0 points if no attempt made
#
#
# **Retrieving your work**
#
# This and all future homework .md files are written in Markdown. The .md file is rendered as an .html file for easier viewing. This and all future homework assignments are located in the **homework** directory within the **stat440-fa21-course-content** repo, i.e. **stat440-fa21-course-content/homework** in GHE. It is always recommended that you **pull** (or refresh) the **stat440-fa21-course-content** repo to ensure that you have the most updated version of all course content including the homework assignments. After pulling (or refreshing) the **stat440-fa21-course-content** repo, the homework file will be in the homework directory. Once you have accessed the .md file, copy all text from the .md file and paste all text into your reproducible document file (either .Rmd or .ipynb file).
#
# **Submitting your work**
#
# In your individual student repo (named as your netID), you are to submit ***two*** files:
#
# a. Your reproducible document file (either .Rmd or .ipynb file) which should be saved as homework##-netID.Rmd or homework##-netID.ipynb depending on your preferred software. For example, my homework 01 file would be saved as homework01-kinson2.Rmd.
#
# b. Your rendered reproducible document file (.html) which should be saved as homework##-netID.html. For example, my homework 01 file would be saved as homework01-kinson2.html.
#
# **Do not place your files in a sub-directory (or folder).** You have an unlimited number of submissions, but only the latest proper submission (commit and push) will be viewed and graded. You are allowed to only use one software language per homework file. This means that you cannot mix software languages (R and Python) in one single homework file. **Remember the .Rmd (or .ipynb) file needs to render properly to .html before submitting.**
#
#
# ***
#
# Undergraduates are expected to complete the problems **#1-#8**. Graduate students are expected to complete all problems.
#
# **The following problems should be completed by you as an individual. If any problem asks you a particular question, be sure to answer it completely (with code, written sentences, or both). Written sentences should not appear in code chunks or code cells. Written sentences should appear in Markdown syntax unless specifically stated otherwise.**
#
# ***Do not change anything in this file above the double line. Doing so will prevent your homework from being graded.***
#
# ***
# ***
#
# ### Use only one programming language for this entire homework assignment. Use the URLs to access the data (if any). No local files allowed.
#
# **#1** (Markdown) Using Markdown syntax, make a numbered list with your first name in normal text as the first item and your last name in italic text as the second item.
#
# Answers will vary, but must be a numbered list. Graded for completeness. For example,
#
# 1. Chris
#
# 2. *Kinson*
#
# **#2** (Syllabus, Three Ways to Interact with this Course, Markdown) Which of the following are ways (a--e) to interact with this course? Place your answers in bold text.
#
# a. **Using GHE**
# b. Using GitHub.com
# c. **Using Git from the command line**
# d. **Using Git with RStudio as a git client**
# e. Using Git with chriskinson.com
#
# **#3** (Loops and conditional execution, Markdown) **Index-controlled** loops are those in which repetitive actions are repeated for a predetermined number of times and stopped when the that number of times is reached. If the text in bold is the term that makes the statement true, then write TRUE below in all caps. If the text in bold is the term that makes the statement false, then write FALSE below in all caps and write the correct term in bold text in a new line under FALSE.
#
# TRUE
#
# **#4** (Accessing and importing data) **Import the following datasets using a programming language and their corresponding data URLs, and print the structure of each.** Read the data descriptions to help verify the import was successful.
#
# - Champaign County Sheriff Office & Jail Data and its data URL https://github-dev.cs.illinois.edu/stat440-fa21/stat440-fa21-course-content/raw/master/data/ccso-jail-data.dat or Box data URL https://uofi.box.com/shared/static/lurfpdqk63au11yzra4a88sxizda0iz5.dat.
#
#   - The dataset (a .dat file) contains over 11082 observations and 40 columns for individuals who were booked into jail in Champaign County. The individuals are not identifiable based on personal identity, but they are given unique jacket numbers. Some rows in the data appear more than once because of multiple crimes being assigned to one person. But there is also the possibility of there being recidivists. A recidivist is a person who goes to jail repeatedly (more than one datetime). The demographics of the people, reasons for being booked, and crime code are also given in the data. The original source is the Champaign County Sheriff Office & Jail (CCSO).
#
# - Chicago Food Inspections Data and its GHE data URL https://github-dev.cs.illinois.edu/stat440-fa21/stat440-fa21-course-content/raw/master/data/chicago-food-inspections-data.csv or Box data URL https://uofi.box.com/shared/static/lwwzlv2sulip1p8qoqqghmw0pouso0wk.csv
#
#   - This dataset (a .csv file) contains 18751 observations and 22 columns. The observations are places that serve food including grocery stores, butchers, bakeries, restaurants, school cafeterias, gas stations, and delis throughout the city limits of Chicago. These establishments pass, fail, or have certain conditions associated with passing the inspection. Read the two links - [link01](https://data.cityofchicago.org/api/assets/BAD5301B-681A-4202-9D25-51B2CAE672FF) and [link02](http://dev.cityofchicago.org/open%20data/data%20portal/2018/06/29/food-violations-changes.html) for more details about the data values. The original source is the City of Chicago Data Portal. **If you have difficulty accessing the two Chicago Food Inspections links from the original source, please use these  [alt-link01](https://github-dev.cs.illinois.edu/stat440-fa21/stat440-fa21-course-content/raw/master/data/chicago-food-data-key01.pdf) and [alt-link02](https://github-dev.cs.illinois.edu/stat440-fa21/stat440-fa21-course-content/raw/master/data/chicago-food-data-key02.pdf) links instead.**

# %%
import pandas as pd
jail_data = pd.read_csv('https://uofi.box.com/shared/static/lurfpdqk63au11yzra4a88sxizda0iz5.dat')
jail_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11082 entries, 0 to 11081
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   booking_number              11082 non-null  float64
#  1   booking_date                11082 non-null  object
#  2   booking_time                11082 non-null  object
#  3   Last_name                   11082 non-null  object
#  4   First_name                  11082 non-null  object
#  5   jacket_number               11082 non-null  int64
#  6   jacket_type                 11082 non-null  object
#  7   released_date               11082 non-null  object
#  8   released_time               11082 non-null  object
#  9   arrest_agency               10905 non-null  object
#  10  age arrest                  11082 non-null  int64
#  11  age releas                  11082 non-null  int64
#  12  days jail                   11082 non-null  int64
#  13  hours                       11082 non-null  int64
#  14  maritial_status             11025 non-null  object
#  15  employment_status           10900 non-null  object
#  16  city                        11076 non-null  object
#  17  race                        10983 non-null  object
#  18  sex                         11036 non-null  object
#  19  state                       11070 non-null  object
#  20  zip_code                    10985 non-null  object
#  21  citizenship                 10978 non-null  object
#  22  maritial_status2            11025 non-null  object
#  23  military                    10896 non-null  object
#  24  occupation                  10662 non-null  object
#  25  school                      10529 non-null  object
#  26  prisoner_type               10994 non-null  object
#  27  offense_level               0 non-null      float64
#  28  education_status            0 non-null      float64
#  29  statue                      11062 non-null  object
#  30  crime                       11062 non-null  object
#  31  super high level            10614 non-null  object
#  32  final answer code           10614 non-null  object
#  33  final answer desc           10614 non-null  object
#  34  custody class               2921 non-null   object
#  35  inmate status               0 non-null      float64
#  36  incarc_reason               11030 non-null  object
#  37  booking_reason              0 non-null      float64
#  38  release reason description  10954 non-null  object
#  39  release_reason              0 non-null      float64
# dtypes: float64(6), int64(5), object(29)
# memory usage: 3.4+ MB

# %%
food_data = pd.read_csv('https://uofi.box.com/shared/static/lwwzlv2sulip1p8qoqqghmw0pouso0wk.csv')
food_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18751 entries, 0 to 18750
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Inspection ID               18751 non-null  int64
#  1   DBA Name                    18751 non-null  object
#  2   AKA Name                    18400 non-null  object
#  3   License #                   18749 non-null  float64
#  4   Facility Type               18147 non-null  object
#  5   Risk                        18742 non-null  object
#  6   Address                     18751 non-null  object
#  7   City                        18731 non-null  object
#  8   State                       18750 non-null  object
#  9   Zip                         18738 non-null  float64
#  10  Inspection Date             18751 non-null  object
#  11  Inspection Type             18751 non-null  object
#  12  Results                     18751 non-null  object
#  13  Violations                  13477 non-null  object
#  14  Latitude                    18670 non-null  float64
#  15  Longitude                   18670 non-null  float64
#  16  Location                    0 non-null      float64
#  17  Historical Wards 2003-2015  0 non-null      float64
#  18  Zip Codes                   0 non-null      float64
#  19  Community Areas             0 non-null      float64
#  20  Census Tracts               0 non-null      float64
#  21  Wards                       0 non-null      float64
# dtypes: float64(10), int64(1), object(11)
# memory usage: 3.1+ MB

# %% [markdown]
# **#5** (Handling dates and times) For each dataset imported in **Problem 4**, ensure all date or time columns are treated as date or datetime formats. Now, print the structure of both datasets.

# %%
jail_data['booking_date'] = pd.to_datetime(jail_data['booking_date'])
jail_data['booking_time'] = pd.to_datetime(jail_data['booking_time'])
jail_data['released_date'] = pd.to_datetime(jail_data['released_date'],errors='coerce')
jail_data['released_time'] = pd.to_datetime(jail_data['released_time'])
jail_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11082 entries, 0 to 11081
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   booking_number              11082 non-null  float64
#  1   booking_date                11082 non-null  datetime64[ns]
#  2   booking_time                11082 non-null  datetime64[ns]
#  3   Last_name                   11082 non-null  object
#  4   First_name                  11082 non-null  object
#  5   jacket_number               11082 non-null  int64
#  6   jacket_type                 11082 non-null  object
#  7   released_date               10954 non-null  datetime64[ns]
#  8   released_time               11082 non-null  datetime64[ns]
#  9   arrest_agency               10905 non-null  object
#  10  age arrest                  11082 non-null  int64
#  11  age releas                  11082 non-null  int64
#  12  days jail                   11082 non-null  int64
#  13  hours                       11082 non-null  int64
#  14  maritial_status             11025 non-null  object
#  15  employment_status           10900 non-null  object
#  16  city                        11076 non-null  object
#  17  race                        10983 non-null  object
#  18  sex                         11036 non-null  object
#  19  state                       11070 non-null  object
#  20  zip_code                    10985 non-null  object
#  21  citizenship                 10978 non-null  object
#  22  maritial_status2            11025 non-null  object
#  23  military                    10896 non-null  object
#  24  occupation                  10662 non-null  object
#  25  school                      10529 non-null  object
#  26  prisoner_type               10994 non-null  object
#  27  offense_level               0 non-null      float64
#  28  education_status            0 non-null      float64
#  29  statue                      11062 non-null  object
#  30  crime                       11062 non-null  object
#  31  super high level            10614 non-null  object
#  32  final answer code           10614 non-null  object
#  33  final answer desc           10614 non-null  object
#  34  custody class               2921 non-null   object
#  35  inmate status               0 non-null      float64
#  36  incarc_reason               11030 non-null  object
#  37  booking_reason              0 non-null      float64
#  38  release reason description  10954 non-null  object
#  39  release_reason              0 non-null      float64
# dtypes: datetime64[ns](4), float64(6), int64(5), object(25)
# memory usage: 3.4+ MB

# %%
jail_data
# Out:
#        booking_number booking_date        booking_time Last_name First_name  \
# 0        2.017000e+11   2019-02-26 2021-10-11 08:42:42   CAMERON   BRITTAIN
# 1        2.018000e+11   2019-05-03 2021-10-11 20:07:41  MARSHALL     TRAVIS
# 2        2.019000e+11   2019-01-01 2021-10-11 00:25:06   STURKEY     ROBERT
# 3        2.019000e+11   2019-01-01 2021-10-11 02:36:57  KAVANAGH       JOHN
# 4        2.019000e+11   2019-01-01 2021-10-11 02:36:57  KAVANAGH       JOHN
# ...               ...          ...                 ...       ...        ...
# 11077    2.019000e+11   2019-12-31 2021-10-11 22:55:43   TALBOTT     DANIEL
# 11078    2.019000e+11   2019-12-31 2021-10-11 22:55:43   TALBOTT     DANIEL
# 11079    2.019000e+11   2019-12-31 2021-10-11 22:55:43   TALBOTT     DANIEL
# 11080    2.019000e+11   2019-12-31 2021-10-11 23:07:23   COCHRAN   CHRISTAL
# 11081    2.019000e+11   2019-12-31 2021-10-11 23:07:23   COCHRAN   CHRISTAL
#
#        jacket_number jacket_type released_date       released_time  \
# 0            1053702           A    2019-02-26 2021-10-11 11:26:22
# 1             963832           A    2019-07-11 2021-10-11 01:31:12
# 2            1043842           A    2019-01-01 2021-10-11 11:36:14
# 3            1071560           A    2019-01-01 2021-10-11 12:56:10
# 4            1071560           A    2019-01-01 2021-10-11 12:56:10
# ...              ...         ...           ...                 ...
# 11077        1075214           A    2020-01-06 2021-10-11 13:55:25
# 11078        1075214           A    2020-01-06 2021-10-11 13:55:25
# 11079        1075214           A    2020-01-06 2021-10-11 13:55:25
# 11080        1065923           A    2020-01-02 2021-10-11 15:03:59
# 11081        1065923           A    2020-01-02 2021-10-11 15:03:59
#
#                                   arrest_agency  ...  \
# 0                     Mahomet Police Department  ...
# 1                   Champaign Police Department  ...
# 2                   Champaign Police Department  ...
# 3      University of Illinois Police Department  ...
# 4      University of Illinois Police Department  ...
# ...                                         ...  ...
# 11077                  Fisher Police Department  ...
# 11078                  Fisher Police Department  ...
# 11079                  Fisher Police Department  ...
# 11080                 Rantoul Police Department  ...
# 11081                 Rantoul Police Department  ...
#
#                                       crime                  super high level  \
# 0                          DOMESTIC BATTERY                           Violent
# 1           UNLAWFUL POSSESSION OF A WEAPON                      Public Order
# 2                          DOMESTIC BATTERY                           Violent
# 3                        AGGRAVATED BATTERY                           Violent
# 4                   OTHER CRIMINAL OFFENSES  Interfering with Public Officers
# ...                                     ...                               ...
# 11077                 FUGITIVE FROM JUSTICE                             Other
# 11078                   OBSTRUCTING JUSTICE  Interfering with Public Officers
# 11079                 FUGITIVE FROM JUSTICE                             Other
# 11080  SUSPENDED OR REVOKED DRIVERS LICENSE                           Traffic
# 11081  SUSPENDED OR REVOKED DRIVERS LICENSE                           Traffic
#
#        final answer code              final answer desc  \
# 0                    C05                        Battery
# 1                    C18               Weapons Offenses
# 2                    C05                        Battery
# 3                    C05                        Battery
# 4                    C31  Interfering w/Public Officers
# ...                  ...                            ...
# 11077                C86             Warrants & Summons
# 11078                C31  Interfering w/Public Officers
# 11079                C86             Warrants & Summons
# 11080                C28               Traffic Offenses
# 11081                C28               Traffic Offenses
#
#                     custody class inmate status  \
# 0                             NaN           NaN
# 1      Sentenced IDOC (CCSO ONLY)           NaN
# 2                             NaN           NaN
# 3                             NaN           NaN
# 4                             NaN           NaN
# ...                           ...           ...
# 11077       Fugitive from Justice           NaN
# 11078       Fugitive from Justice           NaN
# 11079       Fugitive from Justice           NaN
# 11080                         NaN           NaN
# 11081                         NaN           NaN
#
#                           incarc_reason booking_reason  \
# 0              Arrest - Without Warrant            NaN
# 1      Hold - Department Of Corrections            NaN
# 2              Arrest - Without Warrant            NaN
# 3              Arrest - Without Warrant            NaN
# 4              Arrest - Without Warrant            NaN
# ...                                 ...            ...
# 11077          Arrest - Without Warrant            NaN
# 11078          Arrest - Without Warrant            NaN
# 11079          Arrest - Without Warrant            NaN
# 11080             FTA - Traffic Warrant            NaN
# 11081             FTA - Traffic Warrant            NaN
#
#                        release reason description release_reason
# 0                                           Other            NaN
# 1       Sentenced (transfer) to State Corrections            NaN
# 2                Release on Personal Recognizance            NaN
# 3                                Cash Bond Posted            NaN
# 4                                Cash Bond Posted            NaN
# ...                                           ...            ...
# 11077  Transfer to other county/state authorities            NaN
# 11078  Transfer to other county/state authorities            NaN
# 11079  Transfer to other county/state authorities            NaN
# 11080            Release on Personal Recognizance            NaN
# 11081            Release on Personal Recognizance            NaN
#
# [11082 rows x 40 columns]

# %%
food_data['Inspection Date'] = pd.to_datetime(food_data['Inspection Date'])
food_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18751 entries, 0 to 18750
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Inspection ID               18751 non-null  int64
#  1   DBA Name                    18751 non-null  object
#  2   AKA Name                    18400 non-null  object
#  3   License #                   18749 non-null  float64
#  4   Facility Type               18147 non-null  object
#  5   Risk                        18742 non-null  object
#  6   Address                     18751 non-null  object
#  7   City                        18731 non-null  object
#  8   State                       18750 non-null  object
#  9   Zip                         18738 non-null  float64
#  10  Inspection Date             18751 non-null  datetime64[ns]
#  11  Inspection Type             18751 non-null  object
#  12  Results                     18751 non-null  object
#  13  Violations                  13477 non-null  object
#  14  Latitude                    18670 non-null  float64
#  15  Longitude                   18670 non-null  float64
#  16  Location                    0 non-null      float64
#  17  Historical Wards 2003-2015  0 non-null      float64
#  18  Zip Codes                   0 non-null      float64
#  19  Community Areas             0 non-null      float64
#  20  Census Tracts               0 non-null      float64
#  21  Wards                       0 non-null      float64
# dtypes: datetime64[ns](1), float64(10), int64(1), object(10)
# memory usage: 3.1+ MB

# %% [markdown]
# **#6** (Data reduction, Data expansion) Using the Chicago Food Inspections Data imported in **Problem 4**, the data description and details in the links in **Problem 4**, and a programming language, create a new data object named `inspections` that does the following in this order:
#
# 1. filters inspection dates to after September 01, 2011
#
# 2. mutates a new column called "pass_or_not" which equals 1 if the restaurant passes the inspection, 0 if the restaurant passes with conditions, 0 if the restaurant fails, and NA otherwise
#
# 3. de-selects the following columns: "Address", "Census Tracts", "City", "Community Areas", "Historical Wards 2003-2015", "Location", "State", "Wards", and "Zip Codes"
#
# 4. drops all missing values among the remaining columns (e.g. if one field is missing a value for a single row, then that row must be removed)
#
# Now, print the first 5 observations and the last 5 observations of the `inspections` data set.

# %%
import numpy as np
inspections20 = food_data[food_data['Inspection Date'] > '2011-09-01']
#d = {'Fail': 0, 'Pass': 1,'Pass w/ Conditions': 0}
inspections20.assign(pass_or_not = lambda dataframe: dataframe['Results'].map(lambda Results: 1.0 if Results == 'Pass' else 0.0) )
inspections10 = inspections20.drop(columns=['Address', 'Census Tracts', 'City', 'Community Areas', 
                                      'Historical Wards 2003-2015',
                                      'Location', 'State', 'Wards', 'Zip Codes'])
inspections = inspections10.dropna()
print(inspections.head())
print(inspections.tail())
# Out:
#        Inspection ID                       DBA Name  \
# 12672         634452          SMYSER PRIMARY CENTER
# 12673         614455  MARY SEARS CHILDREN'S ACADEMY
# 12674         596426         STARBUCKS COFFEE #2929
# 12675         612435                  RESIDENCE INN
# 12677         565482          CORDI - MARIAN CENTER
#
#                             AKA Name  License #                 Facility Type  \
# 12672          SMYSER PRIMARY CENTER  2510144.0                        School
# 12673  MARY SEARS CHILDREN'S ACADEMY  1964130.0            Daycare Combo 1586
# 12674               STARBUCKS COFFEE  1422751.0                    Restaurant
# 12675                  RESIDENCE INN  1869250.0                    Restaurant
# 12677          CORDI - MARIAN CENTER  1305923.0  Children's Services Facility
#
#                   Risk      Zip Inspection Date Inspection Type  \
# 12672    Risk 1 (High)  60634.0      2011-09-02         Canvass
# 12673    Risk 1 (High)  60605.0      2011-09-02         Canvass
# 12674  Risk 2 (Medium)  60659.0      2011-09-02     Tag Removal
# 12675  Risk 2 (Medium)  60654.0      2011-09-02         Canvass
# 12677    Risk 1 (High)  60607.0      2011-09-02         Canvass
#
#                   Results                                         Violations  \
# 12672                Fail  24. DISH WASHING FACILITIES: PROPERLY DESIGNED...
# 12673                Pass  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...
# 12674  Pass w/ Conditions  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...
# 12675                Fail  3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATUR...
# 12677                Pass  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
#
#         Latitude  Longitude
# 12672  41.946738 -87.781534
# 12673  41.865931 -87.627240
# 12674  41.992345 -87.710323
# 12675  41.889634 -87.629744
# 12677  41.867986 -87.655307
#        Inspection ID                         DBA Name  \
# 18742         531764             FRIENDLY FOOD MARKET
# 18744         545719              PIZZA RIBS & THINGS
# 18745         531763  New Grand Chinese Kitchen, Inc.
# 18747         545721            GRAND CHINESE KITCHEN
# 18748         664310                 DELICIAS BRIANNA
#
#                         AKA Name  License #      Facility Type           Risk  \
# 18742       FRIENDLY FOOD MARKET  2133952.0  CONVENIENCE STORE   Risk 3 (Low)
# 18744        PIZZA RIBS & THINGS     3932.0         Restaurant  Risk 1 (High)
# 18745  New Grand Chinese Kitchen  2008605.0         Restaurant  Risk 1 (High)
# 18747      GRAND CHINESE KITCHEN    21253.0         Restaurant  Risk 1 (High)
# 18748           DELICIAS BRIANNA  2133945.0         Restaurant  Risk 1 (High)
#
#            Zip Inspection Date          Inspection Type Results  \
# 18742  60621.0      2011-12-30    License Re-Inspection    Fail
# 18744  60628.0      2011-12-30                Complaint    Fail
# 18745  60609.0      2011-12-30     Short Form Complaint    Fail
# 18747  60620.0      2011-12-30  Complaint Re-Inspection    Pass
# 18748  60625.0      2011-12-30                  License    Fail
#
#                                               Violations   Latitude  Longitude
# 18742  2. FACILITIES TO MAINTAIN PROPER TEMPERATURE -...  41.764736 -87.628417
# 18744  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.707432 -87.613372
# 18745  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.796235 -87.630405
# 18747  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.736374 -87.627232
# 18748  12. HAND WASHING FACILITIES: WITH SOAP AND SAN...  41.970773 -87.688830

# %% [markdown]
# **#7** (Data reduction, Data expansion, Markdown) Use the `inspections` data object in **Problem 6** and a programming language applying data management concepts to answer the following question in Markdown syntax and complete sentence(s):
#
# - Among the businesses that failed their inspections, what was the third most common facility type?
#
# **You must answer in Markdown syntax in a complete sentence and show code as evidence of your answer.**

# %% [markdown]
# Among the businesses that failed their inspections, the third most common facility type is school.

# %%
inspections[inspections['Results'] == 'Fail']['Facility Type'].value_counts()
# Out:
# Restaurant                         705
# Grocery Store                      278
# School                              88
# Daycare (2 - 6 Years)               23
# Bakery                              17
# Wholesale                           14
# Daycare Above and Under 2 Years     13
# Daycare Combo 1586                  11
# Children's Services Facility        11
# Liquor                               9
# Mobile Food Dispenser                8
# Long Term Care                       7
# Catering                             5
# Golden Diner                         4
# CONVENIENCE                          4
# Hospital                             3
# WINE TASTING BAR                     2
# PACKAGED LIQUOR                      2
# CATERED EVENTS                       2
# RETAIL FOOD/GAS STATION              2
# NOT FOR PROFIT                       2
# STADIUM                              2
# CONVENIENCE STORE                    2
# ROOFTOP                              1
# GAS STATION/MINI MART                1
# HOTEL                                1
# RESTAURANT/GAS STATION               1
# coffee shop                          1
# GROCERY/CAFE                         1
# Daycare (2 Years)                    1
# MOBILE FOOD TRUCK                    1
# BAKERY/DELI                          1
# AFTER SCHOOL PROGRAM                 1
# TAVERN                               1
# GROCERY/RESTAURANT                   1
# GAS STATION                          1
# GAS STATION/STORE GROCERY            1
# RESTAURANT/HOSPITAL                  1
# Name: Facility Type, dtype: int64

# %% [markdown]
# **#8** (Data reduction, Data expansion) Using the Champaign County Sheriff Office & Jail Data imported in **Problem 4**, the data description and details in the links in **Problem 4**, and a programming language, create a new data object named `inmates` that does the following in this order:
#
# 1. mutates a new column "booking_date_time" that glues "booking_date" with "booking_time"
#
#     1. **"booking_date_time" should be formatted as a datetime format**
#
# 2. mutates a new column "released_date_time" that glues "released_date" and "released_time" columns
#
#     1. **"released_date_time" should be formatted as a datetime format**
#
# 3. mutates 5 new columns based on the "booking_date_time" and "released_date_time" columns to compute how much time people spent in jail (as integers): (1) "years", (2) "days", (3) "hours", (4) "minutes", (5) "seconds"
#
#     1. years should represent the number of full years spent in jail (i.e. "years" would be 0 if the person did not spend at least 365 days in jail otherwise years would be an integer)
#     2. days should represent the number of days after years (i.e. "days" should always be less than 365)
#     3. hours should represent the number of hours after days (i.e. "hours" should always be less than 24)
#     4. minutes should represent the number of minutes after hours (i.e. "minutes" should always be less than 60)
#     5. seconds should represent the number of seconds after minutes (i.e. "seconds" should always be less than 60)
#
# 4. mutates a new column "time_spent_in_jail1" which adds together the "years", "days", "hours", "minutes", and "seconds" columns representing the duration of time (in hours as a double)
#
# 5. mutates a new column "time_spent_in_jail2" which uses the difference in time between "booking_date_time" and "released_date_time" columns representing the duration of time spent in jail (in hours as a double)
#
# 6. renames any columns with the word "booking" such that "booking" becomes "booked"
#
# Now, print the first 10 observations of `inmates` data but only selecting the columns: "jacket_number", "time_spent_in_jail1", and "time_spent_in_jail2".

# %%
import numpy as np
inmates = jail_data.copy()
inmates['booking_date_time'] = pd.to_datetime(inmates.apply(lambda x: str(x.booking_date) + str(x.booking_time), axis=1))
inmates['released_date_time'] = pd.to_datetime(inmates.apply(lambda x: str(x.released_date) + str(x.released_time), 
                                                           axis=1), errors='coerce')
diff = (inmates.released_date_time-inmates.booking_date_time)# time difference 
inmates['years'] = diff.apply(lambda x: x.days // 365)
inmates['days'] = diff.apply(lambda x: (x.days % 365))
inmates['hours'] = diff.apply(lambda x: x.seconds // (60*60))
inmates['minutes'] = diff.apply(lambda x: (x.seconds % (60*60)) // 60)
inmates['seconds'] = diff.apply(lambda x: x.seconds % 60)
inmates['time_spent_in_jail1'] = inmates.apply(lambda x: x.years*365*24 + x.days*24 + x.hours 
                                             + np.double(x.minutes)/60.0 + np.double(x.seconds)/60.0/60.0, axis=1)
inmates['time_spent_in_jail2'] = diff.apply(lambda x: x.days * 24 + x.seconds / 3600)
inmates.rename(lambda x: x.replace('booking','booked'), axis=1, inplace=True)
inmates[['jacket_number', 'time_spent_in_jail1' ,'time_spent_in_jail2']].head(10)
# Out:
#    jacket_number  time_spent_in_jail1  time_spent_in_jail2
# 0        1053702             2.727778             2.727778
# 1         963832          1637.391944          1637.391944
# 2        1043842            11.185556            11.185556
# 3        1071560            10.320278            10.320278
# 4        1071560            10.320278            10.320278
# 5        1071560            10.320278            10.320278
# 6          10894          1390.816667          1390.816667
# 7          10894          1390.816667          1390.816667
# 8          10894          1390.816667          1390.816667
# 9          10894          1390.816667          1390.816667

# %% [markdown]
# **#9** (Data reduction, Data expansion, Markdown) Use the `inmates` data object in **Problem 8** and a programming language applying data management concepts to answer the following questions in Markdown syntax and complete sentence(s):
#
# - Are "time_spent_in_jail1" and "time_spent_in_jail2" practically the same?
#
# **You must answer in Markdown syntax in a complete sentence and show code as evidence of your answer.**

# %% [markdown]
# Yes, "time_spent_in_jail1" and "time_spent_in_jail2" are practically the same.

# %%
all(abs(inmates.time_spent_in_jail1[i]-inmates.time_spent_in_jail2[i])<0.001 for i in range(len(inmates))
   if inmates.time_spent_in_jail2[i] == inmates.time_spent_in_jail2[i])
# Out:
# True

# %% [markdown]
# **#10** (Data reduction, Data expansion, Markdown) Use the `inmates` data object in **Problem 8** and a programming language applying data management concepts to answer the following questions in Markdown syntax and complete sentence(s):
#
# - Which crimes are associated with the person who spent the most time in jail ("time_spent_in_jail1")?
#
# **You must answer in Markdown syntax in a complete sentence and show code as evidence of your answer.**

# %% [markdown]
# The crimes associated with the person who spent the most time in jail ("time_spent_in_jail1") are: AGGRAVATED DOMESTIC BATTERY, CRIMINAL SEXUAL ASSAULT, OTHER TRAFFIC OFFENSES, FLEEING & ELUDING OR ATTEMPTING TO FLEE & ELUDE, PAROLE REVOCATION, VIOLATION OF ORDERS OF PROTECTION.

# %%
inmates[inmates.time_spent_in_jail1 == max(inmates.time_spent_in_jail1)].crime.unique()
# Out:
# array(['AGGRAVATED DOMESTIC BATTERY', 'CRIMINAL SEXUAL ASSAULT',
#        'OTHER TRAFFIC OFFENSES',
#        'FLEEING & ELUDING OR ATTEMPTING TO FLEE & ELUDE',
#        'PAROLE REVOCATION', 'VIOLATION OF ORDERS OF PROTECTION'],
#       dtype=object)
